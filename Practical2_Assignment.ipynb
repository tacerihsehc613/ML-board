# %% [markdown]
# <a href="https://colab.research.google.com/github/tacerihsehc613/ML-board/blob/main/Practical2_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# The first thing we need to do is to import pandas
import pandas as pd

# We will aslo change how the floating point numbers are displayed
pd.set_option("display.float_format", lambda x: f"{x:.5f}")

# %%
names = ['Alice', 'Bob', 'Charlie']
animals = ['Dog', 'Cat', None]
age = [27, 12, 43]
sex = ['Female', 'Male', 'Male']

# %%
people = list(zip(names, animals, age, sex))
print(people)
# Out:
# [('Alice', 'Dog', 27, 'Female'), ('Bob', 'Cat', 12, 'Male'), ('Charlie', None, 43, 'Male')]

# %%
df = pd.DataFrame(data=people, columns=['Names','Animals','Age','Sex'])
print(df)
# Out:
#      Names Animals  Age     Sex
# 0    Alice     Dog   27  Female
# 1      Bob     Cat   12    Male
# 2  Charlie    None   43    Male

# %%
df.to_csv('test_people.csv', index=False, header=True)

# %%
df = pd.read_csv('test_people.csv')
print(df)
# Out:
#      Names Animals  Age     Sex
# 0    Alice     Dog   27  Female
# 1      Bob     Cat   12    Male
# 2  Charlie     NaN   43    Male

# %%
print(df.describe())
# Out:
#            Age
# count  3.00000
# mean  27.33333
# std   15.50269
# min   12.00000
# 25%   19.50000
# 50%   27.00000
# 75%   35.00000
# max   43.00000

# %%
print(f"Here you will see the names: \n{df['Names']}")
print(f"\nHere you will see the animals: \n{df['Animals']}")
print(f"\nHere you will see the ages: \n{df['Age']}")
print(f"\nHere you will see the sex: \n{df['Sex']}")
# Out:
# Here you will see the names:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Names, dtype: object
#
# Here you will see the animals:
# 0    Dog
# 1    Cat
# 2    NaN
# Name: Animals, dtype: object
#
# Here you will see the ages:
# 0    27
# 1    12
# 2    43
# Name: Age, dtype: int64
#
# Here you will see the sex:
# 0    Female
# 1      Male
# 2      Male
# Name: Sex, dtype: object

# %%
male, female = df['Sex'].value_counts()
print(f"Here we have {male} male(s) and {female} female(s).")
# Out:
# Here we have 2 male(s) and 1 female(s).

# %%
# finding the mean value of the ages (with 2 decimals)
print(f"mean: {df['Age'].mean():.2f}")
# and the standard deviation (with 2 decimals)
print(f"std: {df['Age'].std():.2f}")
# Out:
# mean: 27.33
# std: 15.50

# %%
# Downloading the titanic dataset
# !wget https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv
# Out:
# --2022-04-09 12:04:14--  https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv
# Resolving web.stanford.edu (web.stanford.edu)... 171.67.215.200, 2607:f6d0:0:925a::ab43:d7c8
# Connecting to web.stanford.edu (web.stanford.edu)|171.67.215.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44225 (43K) [text/csv]
# Saving to: ‘titanic.csv.2’
#
# titanic.csv.2       100%[===================>]  43.19K  --.-KB/s    in 0.04s
#
# 2022-04-09 12:04:14 (1.11 MB/s) - ‘titanic.csv.2’ saved [44225/44225]

# %%
# ASSIGNMENT:
# Load the data and get familiar with it 

df = pd.read_csv('titanic.csv')
print(df)
df.head()
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex      Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# 0      male 22.00000                        1                        0
# 1    female 38.00000                        1                        0
# 2    female 26.00000                        0                        0
# 3    female 35.00000                        1                        0
# 4      male 35.00000                        0                        0
# ..      ...      ...                      ...                      ...
# 882    male 27.00000                        0                        0
# 883  female 19.00000                        0                        0
# 884  female  7.00000                        1                        2
# 885    male 26.00000                        0                        0
# 886    male 32.00000                        0                        0
#
#         Fare
# 0    7.25000
# 1   71.28330
# 2    7.92500
# 3   53.10000
# 4    8.05000
# ..       ...
# 882 13.00000
# 883 30.00000
# 884 23.45000
# 885 30.00000
# 886  7.75000
#
# [887 rows x 8 columns]
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex      Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male 22.00000                        1                        0  7.25000
# 1  female 38.00000                        1                        0 71.28330
# 2  female 26.00000                        0                        0  7.92500
# 3  female 35.00000                        1                        0 53.10000
# 4    male 35.00000                        0                        0  8.05000

# %%
print(df.iloc[:,0])
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 882    0
# 883    1
# 884    0
# 885    1
# 886    0
# Name: Survived, Length: 887, dtype: int64

# %%
# ASSIGNMENT:
# Count the number of males and females
"""
male, female = ...
"""
male, female= df['Sex'].value_counts()
print(male, female)
# Out:
# 573 314

# %%
# ASSIGNMENT:
# Find the mean fare
print(f"mean: {df['Fare'].mean():.2f}")
# Find the standard deviation of the fare
print(f"std: {df['Fare'].std():.2f}")
# Out:
# mean: 32.31
# std: 49.78

# %%
died=df['Survived'].eq(1)
print(died)
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 882    False
# 883     True
# 884    False
# 885     True
# 886    False
# Name: Survived, Length: 887, dtype: bool

# %%
# ASSIGNMENT:
# Count how many survived (1) and how many died (0)

# YOUR CODE HERE

died=df['Survived'].eq(0).sum()
survived=df['Survived'].eq(1).sum()
print(died, survived)
# Out:
# 545 342

# %%
# ASSIGNMENT:
# count how many women and men survived

# YOUR CODE HERE
women_survived=df[(df['Survived']==1) & (df['Sex']=='female')].value_counts()
men_survived=df[(df['Survived']==1) & (df['Sex']=='male')].value_counts()
print(women_survived.count())
print(men_survived.count())
# Out:
# 233
# 109

# %%
# ASSIGNMENT (1):
# Separate the dataset from Titanic into X and y,
# where y is the column Survived, and X is the rest.
# Inspect the data. Look at for instance the function "describe" in pandas

# YOUR CODE HERE
import numpy as np
X = df
y = df['Survived']
X = X.drop(columns=['Survived'], axis=1)
print('-------------')

# ASSIGNMENT (2):
# Standardize the data by subtracting the mean and dividing by the standard deviation.
# Inpect the data again to see that the mean is (close to) zero and the standard deviation is one.

X_mean=X.mean(axis=0,skipna=False)
X_std=X.std(axis=0,skipna=False)
Standardized_X=(X-X_mean) / X_std
Standardized_X['Name']=X['Name']
Standardized_X['Sex']=X['Sex']
X=Standardized_X
#print(X.std(axis=0,skipna=False))
# Out:
# -------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.

# %%
# import the relevant libraries
import matplotlib.pyplot as plt
import numpy as np

# %%
# examples of some datapoint
x = [1,2,3,4]
y = [2,3.5,7,8.2]

# plotting the data using matplotlib.pyplot.plot
plt.plot(x, y)

# It is important to add labels for the axes and a title
plt.xlabel("x")
plt.ylabel("y")
plt.title("Plotting with matplotlib")
# and always end with show(), which will show you the plot.
plt.show()

# %%
# Vertical subplot

plt.style.use('bmh')

t = np.arange(0.0, 1.0, 0.01)
sin = np.sin(2*np.pi*t)
cos = np.cos(2*np.pi*t)

fig = plt.figure()
fig.suptitle("Sine and cosine for different t", fontsize=18)

ax1 = fig.add_subplot(2,1,1)
ax1.plot(t, sin, color='red', lw=2)
ax1.set_ylabel('Amplitude')
ax1.set_xlabel('Time')
ax1.set_title('Sine wave')

ax2 = fig.add_subplot(2,1,2)
ax2.plot(t, cos)
ax2.set_ylabel('Amplitude')
ax2.set_xlabel('Time')
ax2.set_title('Cosine wave')

fig.tight_layout() # comment out this line to see the difference
fig.subplots_adjust(top=0.85)
plt.show()

# %%
# Horizontal subplot

plt.style.use('bmh')

t = np.arange(0.0, 1.0, 0.01)
sin = np.sin(2*np.pi*t)
cos = np.cos(2*np.pi*t)

fig = plt.figure()
fig.suptitle("Sine and cosine for different t", fontsize=18)

ax1 = fig.add_subplot(1,2,1)  # we have changed (2,1,1) to (1,2,1)
ax1.plot(t, sin, color='red', lw=2)
ax1.set_ylabel('Amplitude')
ax1.set_xlabel('Time')
ax1.set_title('Sine wave')

ax2 = fig.add_subplot(1,2,2)  # we have changed (2,1,2) to (1,2,2)
ax2.plot(t, cos)
ax2.set_ylabel('Amplitude')
ax2.set_xlabel('Time')
ax2.set_title('Cosine wave')

fig.tight_layout() # comment out this line to see the difference
fig.subplots_adjust(top=0.85)
plt.show()

# %%
# Here are all the different "pre-configured" styles matplot lib supports
# https://matplotlib.org/tutorials/intermediate/artists.html#sphx-glr-tutorials-intermediate-artists-py 
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# Matrix subplot

fig = plt.figure()
fig.suptitle("Sine and cosine for different t", fontsize=18)

i = 1
for freq in [1, 2, 3]:
  for t_max in [1, 2]:
    t = np.arange(0.0, t_max, 0.01)
    sin = np.sin(2*freq*np.pi*t)
    cos = np.cos(2*freq*np.pi*t)

    ax = fig.add_subplot(3,2,i)
    ax.plot(t, sin, color='red', lw=2, label='sine')
    ax.plot(t, cos, color='blue', lw=2, label='cosine')
    ax.set_ylabel('Amplitude')
    ax.set_xlabel('Time')
    ax.legend(fontsize=6)
    ax.set_title(f'freq = {freq}', fontsize=10)
    i += 1

fig.tight_layout() # comment out this line to see the difference
fig.subplots_adjust(top=0.85)
plt.show()

# %%
# Downloading the titanic dataset
# !wget https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv
# Out:
# --2022-04-09 12:05:00--  https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv
# Resolving web.stanford.edu (web.stanford.edu)... 171.67.215.200, 2607:f6d0:0:925a::ab43:d7c8
# Connecting to web.stanford.edu (web.stanford.edu)|171.67.215.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44225 (43K) [text/csv]
# Saving to: ‘titanic.csv.3’
#
# titanic.csv.3       100%[===================>]  43.19K  --.-KB/s    in 0.04s
#
# 2022-04-09 12:05:00 (1.06 MB/s) - ‘titanic.csv.3’ saved [44225/44225]

# %%
# Load the titanic dataset for plotting
import pandas as pd
df = pd.read_csv('titanic.csv')
#print(df[df['Pclass']==1])
first = df[df['Pclass']==1]
print(first)
# Out:
#      Survived  Pclass                                               Name  \
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 6           0       1                             Mr. Timothy J McCarthy
# 11          1       1                            Miss. Elizabeth Bonnell
# 23          1       1                        Mr. William Thompson Sloper
# ..        ...     ...                                                ...
# 867         1       1    Mrs. Richard Leonard (Sallie Monypeny) Beckwith
# 868         0       1                            Mr. Frans Olof Carlsson
# 875         1       1       Mrs. Thomas Jr (Lily Alexenia Wilson) Potter
# 883         1       1                        Miss. Margaret Edith Graham
# 885         1       1                               Mr. Karl Howell Behr
#
#         Sex      Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# 1    female 38.00000                        1                        0
# 3    female 35.00000                        1                        0
# 6      male 54.00000                        0                        0
# 11   female 58.00000                        0                        0
# 23     male 28.00000                        0                        0
# ..      ...      ...                      ...                      ...
# 867  female 47.00000                        1                        1
# 868    male 33.00000                        0                        0
# 875  female 56.00000                        0                        1
# 883  female 19.00000                        0                        0
# 885    male 26.00000                        0                        0
#
#         Fare
# 1   71.28330
# 3   53.10000
# 6   51.86250
# 11  26.55000
# 23  35.50000
# ..       ...
# 867 52.55420
# 868  5.00000
# 875 83.15830
# 883 30.00000
# 885 30.00000
#
# [216 rows x 8 columns]

# %%
# Horizontal subplot

#t = np.arange(0.0, 1.0, 0.01)                              
first = df[df['Pclass']==1]
second = df[df['Pclass']==2]
third = df[df['Pclass']==3]

fig = plt.figure()
fig.suptitle("fare with the class of the ticket", fontsize=18)

ax1 = fig.add_subplot(1,3,1)  
ax1.scatter(first['Pclass'],first['Fare'],color='blue')
ax1.set_ylabel('Fare')
ax1.set_xlabel('Class')
ax1.set_title('First class')

ax2 = fig.add_subplot(1,3,2)  
ax2.scatter(second['Pclass'],second['Fare'],color='red')
ax2.set_ylabel('Fare')
ax2.set_xlabel('Class')
ax2.set_title('Second Class')

ax3 = fig.add_subplot(1,3,3)  
ax3.scatter(third['Pclass'],third['Fare'],color='green')
ax3.set_ylabel('Fare')
ax3.set_xlabel('Class')
ax3.set_title('Third Class')

fig.tight_layout() # comment out this line to see the difference
fig.subplots_adjust(top=0.85)
plt.show()

# %%
# Horizontal subplot

#t = np.arange(0.0, 1.0, 0.01)                              
first = df[df['Pclass']==1]
second = df[df['Pclass']==2]
third = df[df['Pclass']==3]

plt.scatter(first['Pclass'],first['Fare'],color='blue')
plt.scatter(second['Pclass'],second['Fare'],color='red')
plt.scatter(third['Pclass'],third['Fare'],color='green')
plt.ylabel('Fare')
plt.xlabel('Class')
plt.title('fare with the class of the ticket')

plt.show()

# %%
fare = df["Fare"]
plt.hist(fare)
plt.xlabel("Fare")
plt.title("Visualizaion of the fare difference")
plt.show()

# %%
# ASSIGNMENT:
# Plot a histogram over the people who paid less than, or equal to, 150.

fare = df[df['Fare']<=150.]['Fare']
plt.hist(fare)
plt.xlabel("Fare")
plt.title("Visualizaion of the fare difference")
plt.show()

# %%
plt.hist(df['Age'], bins=20)
plt.xlabel("Age")
plt.show()

# %%
# ASSIGNMENT:
# Make a subplot over the Fare, Class, and Age
plt.figure(figsize = [10, 5]) # larger figure size for subplots


plt.subplot(1, 3, 1) 
plt.hist(df['Fare'])
plt.xlabel("Fare")

plt.subplot(1, 3, 2) 
plt.hist(df['Pclass'])
plt.xlabel("Pclass")

plt.subplot(1, 3, 3) 
plt.hist(df['Age'])
plt.xlabel("Age")

plt.show()

# %%
# ASSIGNMENT:
# Make a plot with red dots for all the people who died, and blue dots for the people who survived.

# YOUR CODE HERE




# Horizontal subplot

#t = np.arange(0.0, 1.0, 0.01)                              
first = df[df['Pclass']==1]
second = df[df['Pclass']==2]
third = df[df['Pclass']==3]

plt.scatter(first['Fare'],first['Pclass'],color='blue')
plt.scatter(second['Fare'],second['Pclass'],color='red')
plt.scatter(third['Fare'],third['Pclass'],color='green')
plt.xlabel('Fare')
plt.ylabel('Class')
plt.title('Fare of each class')



plt.show()

# %%
# ASSIGNMENT:
# Calculate how many women and men died and survived.

female_survived=df[(df['Sex']=='female') & (df['Survived']==1)].shape[0]
male_survived=df[(df['Sex']=='male') & (df['Survived']==1)].shape[0]

female_died=df[(df['Sex']=='female') & (df['Survived']==0)].shape[0]
male_died=df[(df['Sex']=='male') & (df['Survived']==0)].shape[0]


plt.bar([0.9,1.9], [female_survived, male_survived] , color='c', label='survived', width=0.2, alpha=0.3)
plt.bar([1.1, 2.1], [female_died, male_died] , color='r', label='died', width=0.2, alpha=0.3)
plt.xticks([1,2], ['Female','Male'])
plt.legend()
plt.show()
